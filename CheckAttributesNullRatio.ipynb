# %%
##----------------------------------------------------------------------###
#@author narumeena
#@description check null ration in each annotation and attributes 
##----------------------------------------------------------------------###

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np

# %%
caddAnnotation = pd.read_csv("../analysis/caddAnnotation/hgmd/GRCh38-v1.5_cadd_anno.tsv",sep="\t",
                              converters={i: str for i in range(250)})

# %%
caddAnnotation.head()
# Out:
#   Chr      End Ref Alt Type Length           AnnoType  Consequence ConsScore  \
# 0   1   939111   C   T  SNV      0   CodingTranscript  STOP_GAINED         8
# 1   1   939111   C   T  SNV      0  RegulatoryFeature   REGULATORY         4
# 2   1  1014143   C   T  SNV      0   CodingTranscript  STOP_GAINED         8
# 3   1  1014143   C   T  SNV      0         Intergenic     UPSTREAM         1
# 4   1  1014143   C   T  SNV      0  RegulatoryFeature   REGULATORY         4
#
#     ConsDetail  ... Freq10000bp Rare10000bp Sngl10000bp  \
# 0  stop_gained  ...          22         115        2408
# 1   regulatory  ...          22         115        2408
# 2  stop_gained  ...          22          87        1622
# 3     upstream  ...          22          87        1622
# 4   regulatory  ...          22          87        1622
#
#   EnsembleRegulatoryFeature dbscSNV-ada_score dbscSNV-rf_score RemapOverlapTF  \
# 0         CTCF Binding Site                NA               NA             24
# ...

# %%
caddAnnotation.shape
# Out:
# (113516, 125)

# %%
caddAnnotation =caddAnnotation.replace('NA', np.nan)

# %%
caddAnnotation.head()
# Out:
#   Chr      End Ref Alt Type Length           AnnoType  Consequence ConsScore  \
# 0   1   939111   C   T  SNV      0   CodingTranscript  STOP_GAINED         8
# 1   1   939111   C   T  SNV      0  RegulatoryFeature   REGULATORY         4
# 2   1  1014143   C   T  SNV      0   CodingTranscript  STOP_GAINED         8
# 3   1  1014143   C   T  SNV      0         Intergenic     UPSTREAM         1
# 4   1  1014143   C   T  SNV      0  RegulatoryFeature   REGULATORY         4
#
#     ConsDetail  ... Freq10000bp Rare10000bp Sngl10000bp  \
# 0  stop_gained  ...          22         115        2408
# 1   regulatory  ...          22         115        2408
# 2  stop_gained  ...          22          87        1622
# 3     upstream  ...          22          87        1622
# 4   regulatory  ...          22          87        1622
#
#   EnsembleRegulatoryFeature dbscSNV-ada_score dbscSNV-rf_score RemapOverlapTF  \
# 0         CTCF Binding Site               NaN              NaN             24
# ...

# %%
#number of null values in each column 
pd.options.display.max_rows = 4000
caddAnnotation.isnull().sum()
# Out:
# Chr                               0
# End                               0
# Ref                               0
# Alt                               0
# Type                              0
# Length                            0
# AnnoType                          0
# Consequence                       0
# ConsScore                         0
# ConsDetail                        0
# GC                                0
# CpG                               0
# motifECount                  107116
# motifEName                   107116
# motifEHIPos                  107116
# motifEScoreChng              108600
# oAA                           58880
# nAA                           58879
# GeneID                        20523
# FeatureID                         0
# GeneName                      20523
# CCDS                          42840
# Intron                       102054
# Exon                          56657
# cDNApos                       56624
# relcDNApos                    56624
# ...

# %%
###hgmd 

hgmdAnnotation = pd.read_csv("../analysis/annovarAnnotation/hgmd/hgmd_annovar.hg38_multianno.csv",sep=",",
                              converters={i: str for i in range(250)})

# %%
hgmdAnnotation.head()
# Out:
#   Chr    Start      End Ref Alt Func.refGene Gene.refGene GeneDetail.refGene  \
# 0   1   939111   939111   C   T       exonic       SAMD11                  .
# 1   1   939111   939111   C   T       exonic       SAMD11                  .
# 2   1  1014143  1014143   C   T       exonic        ISG15                  .
# 3   1  1014143  1014143   C   T       exonic        ISG15                  .
# 4   1  1022225  1022225   G   A       exonic         AGRN                  .
#
#   ExonicFunc.refGene                        AAChange.refGene  ... BP4 BP5 BP6  \
# 0           stopgain  SAMD11:NM_152486:exon6:c.C502T:p.R168X  ...   0   0   0
# 1           stopgain  SAMD11:NM_152486:exon6:c.C502T:p.R168X  ...   0   0   0
# 2           stopgain    ISG15:NM_005101:exon2:c.C163T:p.Q55X  ...   0   0   0
# 3           stopgain    ISG15:NM_005101:exon2:c.C163T:p.Q55X  ...   0   0   0
# 4  nonsynonymous SNV     AGRN:NM_198576:exon2:c.G226A:p.G76S  ...   0   0   0
#
# ...

# %%
hgmdAnnotation.shape
# Out:
# (96105, 149)

# %%
hgmdAnnotation = hgmdAnnotation.replace('.', np.nan)

# %%
#number of null values in each column 
pd.options.display.max_rows = 4000
hgmdAnnotation.isnull().sum()
# Out:
# Chr                                         0
# Start                                       0
# End                                         0
# Ref                                         0
# Alt                                         0
# Func.refGene                                0
# Gene.refGene                                0
# GeneDetail.refGene                      89969
# ExonicFunc.refGene                       8296
# AAChange.refGene                         8296
# Func.knownGene                              0
# Gene.knownGene                              0
# GeneDetail.knownGene                    89951
# ExonicFunc.knownGene                     8087
# AAChange.knownGene                       8087
# Func.ensGene                                0
# Gene.ensGene                                0
# GeneDetail.ensGene                      89996
# ExonicFunc.ensGene                       8235
# AAChange.ensGene                         8235
# ...

# %%
pathogenicClinvar = pd.read_csv("../analysis/joinDataSets/clinvar/clinvar_cadd_annovar_pathogenic_only.tsv",sep="\t")
# Out:
# /home/narumeena/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pathogenicClinvar.shape
# Out:
# (116342, 270)

# %%
pathogenicClinvar.head()
# Out:
#   Chr      End Ref Alt Type  Length          AnnoType     Consequence  \
# 0  10   246791   C   T  SNV       0  CodingTranscript     STOP_GAINED
# 1  10   246791   C   T  SNV       0  CodingTranscript     STOP_GAINED
# 2  10   246791   C   T  SNV       0  CodingTranscript     STOP_GAINED
# 3  10   246791   C   T  SNV       0  CodingTranscript     STOP_GAINED
# 4  10  8069573   G   A  SNV       0  CodingTranscript  NON_SYNONYMOUS
#
#    ConsScore   ConsDetail  ...  BP4  BP5  BP6 BP7  cosmic70            MCAP  \
# 0        8.0  stop_gained  ...    0    0    0   0         .               .
# 1        8.0  stop_gained  ...    0    0    0   0         .               .
# 2        8.0  stop_gained  ...    0    0    0   0         .               .
# 3        8.0  stop_gained  ...    0    0    0   0         .               .
# 4        7.0     missense  ...    0    0    0   0         .  0.831591650612
#
#    REVEL regsnp_fpr regsnp_disease regsnp_splicing_site
# ...

# %%
pathogenicClinvar.shape
# Out:
# (116342, 270)

# %%
pathogenicClinvar = pathogenicClinvar.replace('.', np.nan)
pathogenicClinvar = pathogenicClinvar.replace('NA', np.nan)

# %%
#number of null values in each column 
pd.options.display.max_rows = 4000
pathogenicClinvar.isnull().sum()
# Out:
# Chr                                          0
# End                                          0
# Ref                                          0
# Alt                                          0
# Type                                         0
# Length                                       0
# AnnoType                                     0
# Consequence                                  0
# ConsScore                                    7
# ConsDetail                                   0
# GC                                           0
# CpG                                          0
# motifECount                             108370
# motifEName                              108370
# motifEHIPos                             108370
# motifEScoreChng                         110311
# oAA                                      62499
# nAA                                      62497
# GeneID                                   20945
# FeatureID                                    0
# ...
