# %%
#!/usr/bin/env python3
##@author narumeena
##@description creating a prarallel cordinates plot in plotely 

import numpy as np
import pandas as pd
import dask.dataframe as dd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
pathogenic = dd.read_csv("../analysis/trainingDataSet/pathogenic_with_all_attributes_cat_uniqe.tsv",sep="\t", 
                         converters={i: str for i in range(250)})
#"Chr","End","Ref","Alt","Type","Length","AnnoType","Consequence","ConsScore","ConsDetail","GC","CpG","motifECount","motifEName","motifEHIPos","motifEScoreChng","oAA","nAA","GeneID","FeatureID","GeneName","CCDS","Intron","Exon","cDNApos","relcDNApos","CDSpos","relCDSpos","protPos","relProtPos","Domain","Dst2Splice","Dst2SplType","minDistTSS","minDistTSE","SIFTcat","SIFTval","PolyPhenCat","PolyPhenVal","priPhCons","mamPhCons","verPhCons","priPhyloP","mamPhyloP","verPhyloP","bStatistic","targetScan","mirSVR-Score","mirSVR-E","mirSVR-Aln","cHmm_E1","cHmm_E2","cHmm_E3","cHmm_E4","cHmm_E5","cHmm_E6","cHmm_E7","cHmm_E8","cHmm_E9","cHmm_E10","cHmm_E11","cHmm_E12","cHmm_E13","cHmm_E14","cHmm_E15","cHmm_E16","cHmm_E17","cHmm_E18","cHmm_E19","cHmm_E20","cHmm_E21","cHmm_E22","cHmm_E23","cHmm_E24","cHmm_E25","GerpRS","GerpRSpval","GerpN","GerpS","tOverlapMotifs","motifDist","EncodeH3K4me1-sum","EncodeH3K4me1-max","EncodeH3K4me2-sum","EncodeH3K4me2-max","EncodeH3K4me3-sum","EncodeH3K4me3-max","EncodeH3K9ac-sum","EncodeH3K9ac-max","EncodeH3K9me3-sum","EncodeH3K9me3-max","EncodeH3K27ac-sum","EncodeH3K27ac-max","EncodeH3K27me3-sum","EncodeH3K27me3-max","EncodeH3K36me3-sum","EncodeH3K36me3-max","EncodeH3K79me2-sum","EncodeH3K79me2-max","EncodeH4K20me1-sum","EncodeH4K20me1-max","EncodeH2AFZ-sum","EncodeH2AFZ-max","EncodeDNase-sum","EncodeDNase-max","EncodetotalRNA-sum","EncodetotalRNA-max","Grantham","Dist2Mutation","Freq100bp","Rare100bp","Sngl100bp","Freq1000bp","Rare1000bp","Sngl1000bp","Freq10000bp","Rare10000bp","Sngl10000bp","EnsembleRegulatoryFeature","dbscSNV-ada_score","dbscSNV-rf_score","RemapOverlapTF","RemapOverlapCRawScore","PHRED","Start","Func.refGene","Gene.refGene","GeneDetail.refGene","ExonicFunc.refGene","AAChange.refGene","Func.knownGene","Gene.knownGene","GeneDetail.knownGene","ExonicFunc.knownGene","AAChange.knownGene","Func.ensGene","Gene.ensGene","GeneDetail.ensGene","ExonicFunc.ensGene","AAChange.ensGene","SIFT_score","SIFT_pred","Polyphen2_HDIV_score","Polyphen2_HDIV_pred","Polyphen2_HVAR_score","Polyphen2_HVAR_pred","LRT_score","LRT_pred","MutationTaster_score","MutationTaster_pred","MutationAssessor_score","MutationAssessor_pred","FATHMM_score","FATHMM_pred","RadialSVM_score","RadialSVM_pred","LR_score","LR_pred","VEST3_score","CADD_raw","CADD_phred","GERP++_RS","phyloP46way_placental","phyloP100way_vertebrate","SiPhy_29way_logOdds","Interpro_domain","SIFT_score.1","SIFT_converted_rankscore","SIFT_pred.1","Polyphen2_HDIV_score.1","Polyphen2_HDIV_rankscore","Polyphen2_HDIV_pred.1","Polyphen2_HVAR_score.1","Polyphen2_HVAR_rankscore","Polyphen2_HVAR_pred.1","LRT_score.1","LRT_converted_rankscore","LRT_pred.1","MutationTaster_score.1","MutationTaster_converted_rankscore","MutationTaster_pred.1","MutationAssessor_score.1","MutationAssessor_score_rankscore","MutationAssessor_pred.1","FATHMM_score.1","FATHMM_converted_rankscore","FATHMM_pred.1","PROVEAN_score","PROVEAN_converted_rankscore","PROVEAN_pred","VEST3_score.1","VEST3_rankscore","MetaSVM_score","MetaSVM_rankscore","MetaSVM_pred","MetaLR_score","MetaLR_rankscore","MetaLR_pred","M-CAP_score","M-CAP_rankscore","M-CAP_pred","CADD_raw.1","CADD_raw_rankscore","CADD_phred.1","DANN_score","DANN_rankscore","fathmm-MKL_coding_score","fathmm-MKL_coding_rankscore","fathmm-MKL_coding_pred","Eigen_coding_or_noncoding","Eigen-raw","Eigen-PC-raw","GenoCanyon_score","GenoCanyon_score_rankscore","integrated_fitCons_score","integrated_fitCons_score_rankscore","integrated_confidence_value","GERP++_RS.1","GERP++_RS_rankscore","phyloP100way_vertebrate.1","phyloP100way_vertebrate_rankscore","phyloP20way_mammalian","phyloP20way_mammalian_rankscore","phastCons100way_vertebrate","phastCons100way_vertebrate_rankscore","phastCons20way_mammalian","phastCons20way_mammalian_rankscore","SiPhy_29way_logOdds.1","SiPhy_29way_logOdds_rankscore","Interpro_domain.1","GTEx_V6_gene","GTEx_V6_tissue","dbscSNV_ADA_SCORE","dbscSNV_RF_SCORE","InterVar_automated","PVS1","PS1","PS2","PS3","PS4","PM1","PM2","PM3","PM4","PM5","PM6","PP1","PP2","PP3","PP4","PP5","BA1","BS1","BS2","BS3","BS4","BP1","BP2","BP3","BP4","BP5","BP6","BP7","cosmic70","MCAP","REVEL","regsnp_fpr","regsnp_disease","regsnp_splicing_site"

# %%
pathogenic = pathogenic.loc[pathogenic['Ref'].isin(['A','T','G','C'])]

# %%
pathogenic = pathogenic.loc[pathogenic['Alt'].isin(['A','T','G','C'])]

# %%
tbfs = dd.read_csv("../data/input/tbfs/snp2tfbs_JASPAR_CORE_2014_vertwithout_chr.bed",sep="\t",header=None,
                   names=["Chr","Start","End","Ref","Alt","rsid","tfbs","tfbsName","tbfsScore"], converters={i: str for i in range(250)})

# %%
tbfs.head()
# Out:
#   Chr    End  Start                     Ref Alt         rsid tfbs  \
# 0   1  10615  10616  CCGCCGTTGCAAAGGCGCGCCG   C  rs376342519    1
# 1   1  11011  11012                       C   G  rs544419019    2
# 2   1  13109  13110                       G   A  rs540538026    3
# 3   1  13115  13116                       T   G   rs62635286    2
# 4   1  13117  13118                       A   G  rs200579949    2
#
#             tfbsName tbfsScore
# 0               NRF1        10
# 1         PLAG1,EGR1  609,-186
# 2  ZNF263,PRDM1,SPIB  376,-9,0
# 3       ZNF263,PRDM1    376,-9
# 4       ZNF263,PRDM1    376,-9

# %%
pathogenic[["Chr","End","Ref","Alt"]].head()
# Out:
#   Chr      End Ref Alt
# 0   1  1041582   C   T
# 1   1  1041582   C   T
# 2   1  1042136   T  TC
# 3   1  1051775   G   A
# 4   1  1051775   G   A

# %%
pathogenic_tfbs = dd.merge(pathogenic,tbfs, how='left', on=['Chr', 'End', 'Ref','Alt']).compute()

# %%
#Chr     End     Ref     Alt     Type    Length  AnnoType        Consequence     
#ConsScore       ConsDetail      GC      CpmotifECount      motifEName      
#motifEHIPos     motifEScoreChng oAA     nAA     GeneID  FeatureID       GeneName        
#CCDS       Intron  Exon    cDNApos relcDNApos      CDSpos  relCDSpos       protPos relProtPos     
#Domain  Dst2Splice      Dst2SplType        minDistTSS      minDistTSE      SIFTcat SIFTval 
#PolyPhenCat     PolyPhenVal     priPhCons       mamPhCons verPhCons        priPhyloP       
#mamPhyloP       verPhyloP       bStatistic      targetScan      mirSVR-Score    mirSVR-E  
#mirSVR-Aln       cHmm_E1 cHmm_E2 cHmm_E3 cHmm_E4 cHmm_E5 cHmm_E6 cHmm_E7 cHmm_E8 cHmm_E9 
#cHmm_E10        cHmm_E11        cHmm_E12   cHmm_E13        cHmm_E14        cHmm_E15        
#cHmm_E16        cHmm_E17        cHmm_E18        cHmm_E19        cHmm_E20   cHmm_E21        
#cHmm_E22        cHmm_E23        cHmm_E24        cHmm_E25        GerpRS  GerpRSpval      GerpN   
#GerpS      tOverlapMotifs  motifDist       EncodeH3K4me1-sum       EncodeH3K4me1-max       
#EncodeH3K4me2-sum       EncodeH3K4me2-max  EncodeH3K4me3-sum       EncodeH3K4me3-max       
#EncodeH3K9ac-sum        EncodeH3K9ac-max        EncodeH3K9me3-sum EncodeH3K9me3-max        
#EncodeH3K27ac-sum       EncodeH3K27ac-max       EncodeH3K27me3-sum      EncodeH3K27me3-max      
#EncodeH3K36me3-sum EncodeH3K36me3-max      EncodeH3K79me2-sum      EncodeH3K79me2-max      
#EncodeH4K20me1-sum      EncodeH4K20me1-max EncodeH2AFZ-sum EncodeH2AFZ-max EncodeDNase-sum 
#EncodeDNase-max EncodetotalRNA-sum      EncodetotalRNA-max      Grantham   Dist2Mutation   Freq100bp       
#Rare100bp       Sngl100bp       Freq1000bp      Rare1000bp      Sngl1000bp      Freq10000bp        
#Rare10000bp     Sngl10000bp     EnsembleRegulatoryFeature       dbscSNV-ada_score       dbscSNV-rf_score  
#RemapOverlapTF   RemapOverlapCRawScore   PHRED   Start   Func.refGene    Gene.refGene    GeneDetail.refGene      
#ExonicFunc.refGene AAChange.refGene        Func.knownGene  Gene.knownGene  GeneDetail.knownGene    
#ExonicFunc.knownGene    AAChange.knownGene Func.ensGene    Gene.ensGene    GeneDetail.ensGene      
#ExonicFunc.ensGene      AAChange.ensGene        SIFT_scoreSIFT_pred        Polyphen2_HDIV_score    
#Polyphen2_HDIV_pred     Polyphen2_HVAR_score    Polyphen2_HVAR_pred     LRT_score LRT_pred MutationTaster_score    
#MutationTaster_pred     MutationAssessor_score  MutationAssessor_pred   FATHMM_score    FATHMM_pred        
#RadialSVM_score RadialSVM_pred  LR_score        LR_pred VEST3_score     CADD_raw        CADD_phred      
#GERP++_RS  phyloP46way_placental   phyloP100way_vertebrate SiPhy_29way_logOdds     Interpro_domain SIFT_score.1    
#SIFT_converted_rankscore   SIFT_pred.1     Polyphen2_HDIV_score.1  Polyphen2_HDIV_rankscore        
#Polyphen2_HDIV_pred.1   Polyphen2_HVAR_score.1     Polyphen2_HVAR_rankscore        Polyphen2_HVAR_pred.1   
#LRT_score.1     LRT_converted_rankscore LRT_pred.1MutationTaster_score.1   MutationTaster_converted_rankscore      
#MutationTaster_pred.1   MutationAssessor_score.1        MutationAssessor_score_rankscore   
#MutationAssessor_pred.1 FATHMM_score.1  FATHMM_converted_rankscore      FATHMM_pred.1   PROVEAN_score      
#PROVEAN_converted_rankscore     PROVEAN_pred    VEST3_score.1   VEST3_rankscore MetaSVM_score   MetaSVM_rankscore  
#MetaSVM_pred    MetaLR_score    MetaLR_rankscore        MetaLR_pred     M-CAP_score     M-CAP_rankscore 
#M-CAP_predCADD_raw.1       CADD_raw_rankscore      CADD_phred.1    DANN_score      DANN_rankscore  
#fathmm-MKL_coding_score fathmm-MKL_coding_rankscore        fathmm-MKL_coding_pred  Eigen_coding_or_noncoding       
#Eigen-raw       Eigen-PC-raw    GenoCanyon_score   GenoCanyon_score_rankscore      integrated_fitCons_score        
#integrated_fitCons_score_rankscore      integrated_confidence_value        GERP++_RS.1     GERP++_RS_rankscore     
#phyloP100way_vertebrate.1       phyloP100way_vertebrate_rankscore  phyloP20way_mammalian   
#phyloP20way_mammalian_rankscore phastCons100way_vertebrate      phastCons100way_vertebrate_rankscore       
#phastCons20way_mammalian        phastCons20way_mammalian_rankscore      SiPhy_29way_logOdds.1   
#SiPhy_29way_logOdds_rankscore      Interpro_domain.1       GTEx_V6_gene    GTEx_V6_tissue  dbscSNV_ADA_SCORE       
#dbscSNV_RF_SCORE  InterVar_automated       PVS1    PS1     PS2     PS3     PS4     PM1     PM2     PM3     
#PM4     PM5     PM6     PP1     PPPP3      PP4     PP5     BA1     BS1     BS2     BS3     BS4     BP1     
#BP2     BP3     BP4     BP5     BP6     BP7     cosmic70   MCAP    REVEL   regsnp_fpr      regsnp_disease  
#regsnp_splicing_site

case = pathogenic_tfbs[["Ref","Alt","Consequence","GC","CpG","motifECount","motifEHIPos","oAA","nAA","cDNApos",
           "relcDNApos","CDSpos","relCDSpos","protPos","relProtPos","Domain","Dst2Splice","Dst2SplType",
           "minDistTSS","minDistTSE","SIFTcat","SIFTval","PolyPhenCat","PolyPhenVal","priPhCons","mamPhCons",
           "verPhCons","priPhyloP","mamPhyloP","verPhyloP","bStatistic","cHmm_E1","cHmm_E2","cHmm_E3","cHmm_E4",
           "cHmm_E5","cHmm_E6","cHmm_E7","cHmm_E8","cHmm_E9","cHmm_E10","cHmm_E11","cHmm_E12","cHmm_E13",
           "cHmm_E14","cHmm_E15","cHmm_E16","cHmm_E17","cHmm_E18","cHmm_E19","cHmm_E20","cHmm_E21","cHmm_E22",
           "cHmm_E23","cHmm_E24","cHmm_E25","GerpRS","GerpRSpval","GerpN","GerpS","tOverlapMotifs","motifDist",
           "EncodeH3K4me1-max","EncodeH3K4me2-max","EncodeH3K4me3-max","EncodeH3K9ac-max","EncodeH3K9me3-max",
           "EncodeH3K27ac-max","EncodeH3K27me3-max","EncodeH3K36me3-max","EncodeH3K79me2-max","EncodeH4K20me1-max",
           "EncodeH2AFZ-max","EncodeDNase-max","EncodetotalRNA-max","Grantham","SIFT_score","Polyphen2_HDIV_score",
           "Polyphen2_HVAR_score","LRT_score","MutationTaster_score","MutationAssessor_score","LR_score","GERP++_RS",
           "phyloP100way_vertebrate","SiPhy_29way_logOdds","PROVEAN_score","MetaSVM_score","MetaLR_score",
           "integrated_fitCons_score","phyloP20way_mammalian","phastCons100way_vertebrate",
           "phastCons20way_mammalian","tfbs"]]


case.head()
# Out:
#   Ref Alt     Consequence     GC    CpG motifECount motifEHIPos oAA nAA  \
# 0   A   T        INTRONIC  0.384  0.027          NA          NA  NA  NA
# 1   G   C  NON_SYNONYMOUS   0.57   0.08          NA          NA   A   P
# 2   G   A  NON_SYNONYMOUS  0.563  0.107          NA          NA   G   S
# 3   A   G  NON_SYNONYMOUS  0.576  0.067          NA          NA   K   E
# 4   G   T  NON_SYNONYMOUS  0.642  0.093          NA          NA   G   V
#
#   cDNApos  ... phyloP100way_vertebrate SiPhy_29way_logOdds PROVEAN_score  \
# 0      NA  ...                       .                   .             .
# 1     738  ...                   1.470               8.506         -1.96
# 2     807  ...                   9.869              11.015         -5.81
# 3     625  ...                   1.127              12.576         -0.71
# 4     962  ...                   7.546              16.019         -5.73
#
#   MetaSVM_score MetaLR_score integrated_fitCons_score phyloP20way_mammalian  \
# ...

# %%
#replace ., * , null with NaN 
#case = case.replace('^.$', np.nan)
#case = case.replace('*', np.nan)


case = case.replace('null', np.nan, regex=True)
case = case.replace('Null', np.nan, regex=True)
case = case.replace('NA', np.nan, regex=True)
case = case.replace('.', np.nan)
case = case.replace('-', np.nan)
case = case.replace('*', np.nan)

case.to_csv("../analysis/trainingDataSet/slected_pathogenic.csv", sep="\t",index=False)
case.head()
# Out:
#   Ref Alt     Consequence     GC    CpG motifECount motifEHIPos  oAA  nAA  \
# 0   A   T        INTRONIC  0.384  0.027         NaN         NaN  NaN  NaN
# 1   G   C  NON_SYNONYMOUS   0.57   0.08         NaN         NaN    A    P
# 2   G   A  NON_SYNONYMOUS  0.563  0.107         NaN         NaN    G    S
# 3   A   G  NON_SYNONYMOUS  0.576  0.067         NaN         NaN    K    E
# 4   G   T  NON_SYNONYMOUS  0.642  0.093         NaN         NaN    G    V
#
#   cDNApos  ... phyloP100way_vertebrate SiPhy_29way_logOdds PROVEAN_score  \
# 0     NaN  ...                     NaN                 NaN           NaN
# 1     738  ...                   1.470               8.506         -1.96
# 2     807  ...                   9.869              11.015         -5.81
# 3     625  ...                   1.127              12.576         -0.71
# 4     962  ...                   7.546              16.019         -5.73
#
#   MetaSVM_score MetaLR_score integrated_fitCons_score phyloP20way_mammalian  \
# ...

# %%
case.shape
# Out:
# (113485, 94)

# %%
##human Drive 

human_drive = pd.read_csv("../analysis/trainingDataSet/human_Drive_cadd_annovar_annotation_uniqe.tsv",sep="\t", converters={i: str for i in range(250)})
human_drive.head()
# Out:
#   Chr       End Ref Alt Type Length           AnnoType Consequence ConsScore  \
# 0  16  78208116   G   A  SNV      0         Transcript    INTRONIC         2
# 1  16  78215334   T   C  SNV      0         Transcript    INTRONIC         2
# 2  16  78220722   A   G  SNV      0         Transcript    INTRONIC         2
# 3  16  78221967   G   C  SNV      0  RegulatoryFeature  REGULATORY         4
# 4  16  78221967   G   C  SNV      0         Transcript    INTRONIC         2
#
#    ConsDetail  ... BP4 BP5 BP6 BP7 cosmic70 MCAP REVEL regsnp_fpr  \
# 0      intron  ...   .   .   .   .        .    .     .          .
# 1      intron  ...   .   .   .   .        .    .     .          .
# 2      intron  ...   .   .   .   .        .    .     .          .
# 3  regulatory  ...   .   .   .   .        .    .     .          .
# 4      intron  ...   .   .   .   .        .    .     .          .
#
#   regsnp_disease regsnp_splicing_site
# 0              .                    .
# ...

# %%
human_drive = human_drive.loc[human_drive['Ref'].isin(['A','T','G','C'])]

# %%
human_drive = human_drive.loc[human_drive['Alt'].isin(['A','T','G','C'])]

# %%
human_drive_tfbs = dd.merge(human_drive,tbfs, how='left', on=['Chr', 'End', 'Ref','Alt']).compute()

# %%
control = human_drive_tfbs[["Ref","Alt","Consequence","GC","CpG","motifECount","motifEHIPos","oAA","nAA","cDNApos",
           "relcDNApos","CDSpos","relCDSpos","protPos","relProtPos","Domain","Dst2Splice","Dst2SplType",
           "minDistTSS","minDistTSE","SIFTcat","SIFTval","PolyPhenCat","PolyPhenVal","priPhCons","mamPhCons",
           "verPhCons","priPhyloP","mamPhyloP","verPhyloP","bStatistic","cHmm_E1","cHmm_E2","cHmm_E3","cHmm_E4",
           "cHmm_E5","cHmm_E6","cHmm_E7","cHmm_E8","cHmm_E9","cHmm_E10","cHmm_E11","cHmm_E12","cHmm_E13",
           "cHmm_E14","cHmm_E15","cHmm_E16","cHmm_E17","cHmm_E18","cHmm_E19","cHmm_E20","cHmm_E21","cHmm_E22",
           "cHmm_E23","cHmm_E24","cHmm_E25","GerpRS","GerpRSpval","GerpN","GerpS","tOverlapMotifs","motifDist",
           "EncodeH3K4me1-max","EncodeH3K4me2-max","EncodeH3K4me3-max","EncodeH3K9ac-max","EncodeH3K9me3-max",
           "EncodeH3K27ac-max","EncodeH3K27me3-max","EncodeH3K36me3-max","EncodeH3K79me2-max","EncodeH4K20me1-max",
           "EncodeH2AFZ-max","EncodeDNase-max","EncodetotalRNA-max","Grantham","SIFT_score","Polyphen2_HDIV_score",
           "Polyphen2_HVAR_score","LRT_score","MutationTaster_score","MutationAssessor_score","LR_score","GERP++_RS",
           "phyloP100way_vertebrate","SiPhy_29way_logOdds","PROVEAN_score","MetaSVM_score","MetaLR_score",
           "integrated_fitCons_score","phyloP20way_mammalian","phastCons100way_vertebrate",
           "phastCons20way_mammalian","tfbs"]]


control.head()
# Out:
#   Ref Alt Consequence     GC    CpG motifECount motifEHIPos oAA nAA cDNApos  \
# 0   G   A    INTRONIC  0.503   0.04          NA          NA  NA  NA      NA
# 1   A   C    INTRONIC   0.53  0.013          NA          NA  NA  NA      NA
# 2   T   C    INTRONIC  0.371   0.04          NA          NA  NA  NA      NA
# 3   A   G    INTRONIC  0.391  0.013          NA          NA  NA  NA      NA
# 4   T   C  DOWNSTREAM  0.311  0.013          NA          NA  NA  NA      NA
#
#    ... phyloP100way_vertebrate SiPhy_29way_logOdds PROVEAN_score  \
# 0  ...                       .                   .             .
# 1  ...                       .                   .             .
# 2  ...                       .                   .             .
# 3  ...                       .                   .             .
# 4  ...                       .                   .             .
#
#   MetaSVM_score MetaLR_score integrated_fitCons_score phyloP20way_mammalian  \
# ...

# %%
#replace ., * , null with NaN 
#control = control.replace('.', np.nan, regex=True)
#control = control.replace('*', np.nan, regex=True)
control = control.replace('null', np.nan, regex=True)
control = control.replace('Null', np.nan, regex=True)
control = control.replace('NA', np.nan, regex=True)
control = control.replace('.', np.nan)
control = control.replace('-', np.nan)
control = control.replace('*', np.nan)
control.to_csv("../analysis/trainingDataSet/slected_human_Drive.csv", sep="\t",index=False)
#control.head()

# %%
control.shape
# Out:
# (1674865, 94)
